# %% [markdown]
# ### Import pandas and read in the csv file and set it to a dataframe called df

# %% [markdown]
# ## Setting up python

# %%
import pandas as pd
import numpy as np
#import xml.etree.ElementTree as ET

# %%
import os
os.chdir('/Users/yingli/Development/TopicsInDataScience/topicsindatascience')
#df = pd.read_csv('dhs_service_records_synthesized_final.csv')
df = pd.read_csv("/Users/yingli/Downloads/dhs_service_records_synthesized_final.csv")

# %% [markdown]
# ## Conduct some simple data inspection
#
#  - take a look at the first ten rows, and last 7 rows

# %%
df.head()
# Out:
#    synthetic_data  MCI_UNIQ_ID  CALDR_YR DATE_OF_EVENT  \
# 0  SYNTHETIC DATA         1626      2021    01/31/2021
# 1  SYNTHETIC DATA         1626      2021    02/28/2021
# 2  SYNTHETIC DATA         1626      2021    03/31/2021
# 3  SYNTHETIC DATA         1626      2021    04/30/2021
# 4  SYNTHETIC DATA         1626      2021    05/31/2021
#
#                                              service  GEO_AREA  age  DOB  DOD  \
# 0  Children_Attending_Early_Childhood_Programs_Ma...       NaN    5  NaN  NaN
# 1  Children_Attending_Early_Childhood_Programs_Ma...       NaN    5  NaN  NaN
# 2  Children_Attending_Early_Childhood_Programs_Ma...       NaN    5  NaN  NaN
# 3  Children_Attending_Early_Childhood_Programs_Ma...       NaN    5  NaN  NaN
# 4  Children_Attending_Early_Childhood_Programs_Ma...       NaN    5  NaN  NaN
#
#    GENDER  GENDER_IDENTITY  SEX_ORIENT  LEGAL_SEX     RACE   ETHNICITY  \
# 0  1~Male              NaN         NaN        NaN  1~White  99~Unknown
# 1  1~Male              NaN         NaN        NaN  1~White  99~Unknown
# 2  1~Male              NaN         NaN        NaN  1~White  99~Unknown
# 3  1~Male              NaN         NaN        NaN  1~White  99~Unknown
# 4  1~Male              NaN         NaN        NaN  1~White  99~Unknown
#
#    LIVING_ARRANGEMENT  EMPLOYMENT_STATUS MARITAL_STATUS  \
# 0                 NaN                NaN     99~Unknown
# 1                 NaN                NaN     99~Unknown
# 2                 NaN                NaN     99~Unknown
# 3                 NaN                NaN     99~Unknown
# 4                 NaN                NaN     99~Unknown
#
#                  EDUCATION_LEVEL  VETERAN_FLAG
# 0  9-12~High School (grade 9-12)           NaN
# 1  9-12~High School (grade 9-12)           NaN
# 2  9-12~High School (grade 9-12)           NaN
# 3  9-12~High School (grade 9-12)           NaN
# 4  9-12~High School (grade 9-12)           NaN

# %%
df.tail(7)
# Out:
#          synthetic_data  MCI_UNIQ_ID  CALDR_YR DATE_OF_EVENT   service  \
# 7116127  SYNTHETIC DATA       530696      2021    06/30/2021  Suicides
# 7116128  SYNTHETIC DATA       530765      2021    06/30/2021  Suicides
# 7116129  SYNTHETIC DATA       530832      2021    06/30/2021  Suicides
# 7116130  SYNTHETIC DATA       532121      2021    04/30/2021  Suicides
# 7116131  SYNTHETIC DATA       533991      2021    11/30/2021  Suicides
# 7116132  SYNTHETIC DATA       534127      2021    07/31/2021  Suicides
# 7116133  SYNTHETIC DATA       535156      2021    06/30/2021  Suicides
#
#          GEO_AREA  age  DOB  DOD    GENDER  GENDER_IDENTITY  SEX_ORIENT  \
# 7116127       NaN   21  NaN  NaN  2~Female              NaN         NaN
# 7116128       NaN   15  NaN  NaN  2~Female              NaN         NaN
# 7116129       NaN   17  NaN  NaN    1~Male              NaN         NaN
# 7116130       NaN   22  NaN  NaN  2~Female              NaN         NaN
# 7116131       NaN   16  NaN  NaN    1~Male              NaN         NaN
# 7116132       NaN   19  NaN  NaN    1~Male              NaN         NaN
# 7116133       NaN   24  NaN  NaN    1~Male              NaN         NaN
#
#          LEGAL_SEX     RACE              ETHNICITY  LIVING_ARRANGEMENT  \
# 7116127        NaN  1~White             99~Unknown                 NaN
# 7116128        NaN  1~White             99~Unknown                 NaN
# 7116129        NaN  1~White             99~Unknown                 NaN
# 7116130        NaN  1~White             99~Unknown                 NaN
# 7116131        NaN  1~White             99~Unknown                 NaN
# 7116132        NaN  1~White  2~Not Hispanic/Latinx                 NaN
# 7116133        NaN  1~White             99~Unknown                 NaN
#
#          EMPLOYMENT_STATUS          MARITAL_STATUS  \
# 7116127                NaN              99~Unknown
# 7116128                NaN              99~Unknown
# 7116129                NaN              99~Unknown
# 7116130                NaN  1~Single-Never Married
# 7116131                NaN  1~Single-Never Married
# 7116132                NaN               4~Widowed
# 7116133                NaN  1~Single-Never Married
#
#                        EDUCATION_LEVEL  VETERAN_FLAG
# 7116127                     99~Unknown           NaN
# 7116128                     99~Unknown           NaN
# 7116129                     99~Unknown           NaN
# 7116130  9-12~High School (grade 9-12)           NaN
# 7116131  9-12~High School (grade 9-12)           NaN
# 7116132           GRAD~Graduate Degree           NaN
# 7116133  9-12~High School (grade 9-12)           NaN

# %% [markdown]
# Looks like the last row is completely NaN, also, has a different value for "synthetic_data".

# %% [markdown]
# ### dataframe dimensions, column names, column data types, ranges of column values

# %%
df.shape
# Out:
# (7116134, 20)

# %%
df.columns
# Out:
# Index(['synthetic_data', 'MCI_UNIQ_ID', 'CALDR_YR', 'DATE_OF_EVENT', 'service',
#        'GEO_AREA', 'age', 'DOB', 'DOD', 'GENDER', 'GENDER_IDENTITY',
#        'SEX_ORIENT', 'LEGAL_SEX', 'RACE', 'ETHNICITY', 'LIVING_ARRANGEMENT',
#        'EMPLOYMENT_STATUS', 'MARITAL_STATUS', 'EDUCATION_LEVEL',
#        'VETERAN_FLAG'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7116134 entries, 0 to 7116133
# Data columns (total 20 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   synthetic_data      object
#  1   MCI_UNIQ_ID         int64
#  2   CALDR_YR            int64
#  3   DATE_OF_EVENT       object
#  4   service             object
#  5   GEO_AREA            float64
#  6   age                 int64
#  7   DOB                 float64
#  8   DOD                 float64
#  9   GENDER              object
#  10  GENDER_IDENTITY     float64
#  11  SEX_ORIENT          float64
#  12  LEGAL_SEX           float64
#  13  RACE                object
#  14  ETHNICITY           object
#  15  LIVING_ARRANGEMENT  float64
#  16  EMPLOYMENT_STATUS   float64
#  17  MARITAL_STATUS      object
#  18  EDUCATION_LEVEL     object
#  19  VETERAN_FLAG        float64
# dtypes: float64(9), int64(3), object(8)
# memory usage: 1.1+ GB

# %% [markdown]
#  - another way to check the data types

# %%
df.dtypes
# Out:
# synthetic_data         object
# MCI_UNIQ_ID             int64
# CALDR_YR                int64
# DATE_OF_EVENT          object
# service                object
# GEO_AREA              float64
# age                     int64
# DOB                   float64
# DOD                   float64
# GENDER                 object
# GENDER_IDENTITY       float64
# SEX_ORIENT            float64
# LEGAL_SEX             float64
# RACE                   object
# ETHNICITY              object
# LIVING_ARRANGEMENT    float64
# EMPLOYMENT_STATUS     float64
# MARITAL_STATUS         object
# EDUCATION_LEVEL        object
# VETERAN_FLAG          float64
# dtype: object

# %%
df.nunique()
# Out:
# synthetic_data             1
# MCI_UNIQ_ID           533799
# CALDR_YR                   1
# DATE_OF_EVENT             12
# service                   22
# GEO_AREA                   0
# age                      112
# DOB                        0
# DOD                        0
# GENDER                     3
# GENDER_IDENTITY            0
# SEX_ORIENT                 0
# LEGAL_SEX                  0
# RACE                       7
# ETHNICITY                  3
# LIVING_ARRANGEMENT         0
# EMPLOYMENT_STATUS          0
# MARITAL_STATUS             7
# EDUCATION_LEVEL            8
# VETERAN_FLAG               0
# dtype: int64

# %%
df.groupby("synthetic_data").count()
# Out:
#                 MCI_UNIQ_ID  CALDR_YR  DATE_OF_EVENT  service  GEO_AREA  \
# synthetic_data
# SYNTHETIC DATA      7116134   7116134        7116134  7116134         0
#
#                     age  DOB  DOD   GENDER  GENDER_IDENTITY  SEX_ORIENT  \
# synthetic_data
# SYNTHETIC DATA  7116134    0    0  7116134                0           0
#
#                 LEGAL_SEX     RACE  ETHNICITY  LIVING_ARRANGEMENT  \
# synthetic_data
# SYNTHETIC DATA          0  7116134    7116134                   0
#
#                 EMPLOYMENT_STATUS  MARITAL_STATUS  EDUCATION_LEVEL  \
# synthetic_data
# SYNTHETIC DATA                  0         7116134          7116134
#
#                 VETERAN_FLAG
# synthetic_data
# SYNTHETIC DATA             0

# %%
df["synthetic_data"].value_counts()
# Out:
# synthetic_data
# SYNTHETIC DATA    7116134
# Name: count, dtype: int64

# %% [markdown]
#  - one way to get an overview of the data values

# %%
df.describe()
# Out:
#         MCI_UNIQ_ID   CALDR_YR  GEO_AREA           age  DOB  DOD  \
# count  7.116134e+06  7116134.0       0.0  7.116134e+06  0.0  0.0
# mean   2.674853e+05     2021.0       NaN  3.267702e+01  NaN  NaN
# std    1.544397e+05        0.0       NaN  2.258095e+01  NaN  NaN
# min    1.000000e+00     2021.0       NaN  0.000000e+00  NaN  NaN
# 25%    1.337730e+05     2021.0       NaN  1.300000e+01  NaN  NaN
# 50%    2.675410e+05     2021.0       NaN  3.000000e+01  NaN  NaN
# 75%    4.010820e+05     2021.0       NaN  4.900000e+01  NaN  NaN
# max    5.356080e+05     2021.0       NaN  1.210000e+02  NaN  NaN
#
#        GENDER_IDENTITY  SEX_ORIENT  LEGAL_SEX  LIVING_ARRANGEMENT  \
# count              0.0         0.0        0.0                 0.0
# mean               NaN         NaN        NaN                 NaN
# std                NaN         NaN        NaN                 NaN
# min                NaN         NaN        NaN                 NaN
# 25%                NaN         NaN        NaN                 NaN
# 50%                NaN         NaN        NaN                 NaN
# 75%                NaN         NaN        NaN                 NaN
# max                NaN         NaN        NaN                 NaN
#
#        EMPLOYMENT_STATUS  VETERAN_FLAG
# count                0.0           0.0
# mean                 NaN           NaN
# std                  NaN           NaN
# min                  NaN           NaN
# 25%                  NaN           NaN
# 50%                  NaN           NaN
# 75%                  NaN           NaN
# max                  NaN           NaN

# %% [markdown]
# lots of NAs, so lets count the NA

# %%
df.shape
# Out:
# (7116134, 20)

# %%
df.isna().sum()
# Out:
# synthetic_data              0
# MCI_UNIQ_ID                 0
# CALDR_YR                    0
# DATE_OF_EVENT               0
# service                     0
# GEO_AREA              7116134
# age                         0
# DOB                   7116134
# DOD                   7116134
# GENDER                      0
# GENDER_IDENTITY       7116134
# SEX_ORIENT            7116134
# LEGAL_SEX             7116134
# RACE                        0
# ETHNICITY                   0
# LIVING_ARRANGEMENT    7116134
# EMPLOYMENT_STATUS     7116134
# MARITAL_STATUS              0
# EDUCATION_LEVEL             0
# VETERAN_FLAG          7116134
# dtype: int64

# %%
df.isnull().sum()
# Out:
# synthetic_data              0
# MCI_UNIQ_ID                 0
# CALDR_YR                    0
# DATE_OF_EVENT               0
# service                     0
# GEO_AREA              7116134
# age                         0
# DOB                   7116134
# DOD                   7116134
# GENDER                      0
# GENDER_IDENTITY       7116134
# SEX_ORIENT            7116134
# LEGAL_SEX             7116134
# RACE                        0
# ETHNICITY                   0
# LIVING_ARRANGEMENT    7116134
# EMPLOYMENT_STATUS     7116134
# MARITAL_STATUS              0
# EDUCATION_LEVEL             0
# VETERAN_FLAG          7116134
# dtype: int64

# %% [markdown]
# these columns have only NAs
# ['GEO_AREA', 'DOB', 'DOD', 'GENDER_IDENTITY', 'SEX_ORIENT', 'LEGAL_SEX', 'LIVING_ARRANGEMENT',
#        'EMPLOYMENT_STATUS', 'VETERAN_FLAG']
#
# and there seem to be one row that has NA in all columns? usually it can be the first row or last row. But let's verify.

# %%
df.isna().tail(1)
# Out:
#          synthetic_data  MCI_UNIQ_ID  CALDR_YR  DATE_OF_EVENT  service  \
# 7116133           False        False     False          False    False
#
#          GEO_AREA    age   DOB   DOD  GENDER  GENDER_IDENTITY  SEX_ORIENT  \
# 7116133      True  False  True  True   False             True        True
#
#          LEGAL_SEX   RACE  ETHNICITY  LIVING_ARRANGEMENT  EMPLOYMENT_STATUS  \
# 7116133       True  False      False                True               True
#
#          MARITAL_STATUS  EDUCATION_LEVEL  VETERAN_FLAG
# 7116133           False            False          True

# %% [markdown]
# let's clean up the data frame then, drop last row, drop the columns that only have NAs

# %%
df.tail(1)
# Out:
#          synthetic_data  MCI_UNIQ_ID  CALDR_YR DATE_OF_EVENT   service  \
# 7116133  SYNTHETIC DATA       535156      2021    06/30/2021  Suicides
#
#          GEO_AREA  age  DOB  DOD  GENDER  GENDER_IDENTITY  SEX_ORIENT  \
# 7116133       NaN   24  NaN  NaN  1~Male              NaN         NaN
#
#          LEGAL_SEX     RACE   ETHNICITY  LIVING_ARRANGEMENT  \
# 7116133        NaN  1~White  99~Unknown                 NaN
#
#          EMPLOYMENT_STATUS          MARITAL_STATUS  \
# 7116133                NaN  1~Single-Never Married
#
#                        EDUCATION_LEVEL  VETERAN_FLAG
# 7116133  9-12~High School (grade 9-12)           NaN

# %%
df.dropna(how='all', inplace=True)
df.shape
# Out:
# (7116134, 20)

# %%
df.tail(1)
# Out:
#          synthetic_data  MCI_UNIQ_ID  CALDR_YR DATE_OF_EVENT   service  \
# 7116133  SYNTHETIC DATA       535156      2021    06/30/2021  Suicides
#
#          GEO_AREA  age  DOB  DOD  GENDER  GENDER_IDENTITY  SEX_ORIENT  \
# 7116133       NaN   24  NaN  NaN  1~Male              NaN         NaN
#
#          LEGAL_SEX     RACE   ETHNICITY  LIVING_ARRANGEMENT  \
# 7116133        NaN  1~White  99~Unknown                 NaN
#
#          EMPLOYMENT_STATUS          MARITAL_STATUS  \
# 7116133                NaN  1~Single-Never Married
#
#                        EDUCATION_LEVEL  VETERAN_FLAG
# 7116133  9-12~High School (grade 9-12)           NaN

# %% [markdown]
# df.dropna(how="all") would not remove the last row, we need a way to drop the last row

# %%
# df.dropna(inplace=True) # will drop rows with any NA.

# %% [markdown]
#  - question: what can you observe from the above result?

# %% [markdown]
#  - take a look at 3 random rows, it is important to inspect data beyond the head and tail

# %%
# set seed for random function so that we get same rows when re-run the cell
np.random.seed(17)
np.random.randint(2, df.shape[0],3)
# Out:
# array([ 589043, 5539985, 2078088])

# %%
np.random.randint(3, df.shape[0],3)
# Out:
# array([491929, 828732, 776112])

# %%
# set seed for random function so that we get same rows when re-run the cell
np.random.seed(17)
df.iloc[np.random.randint(0, df.shape[0],3)]
# Out:
#          synthetic_data  MCI_UNIQ_ID  CALDR_YR DATE_OF_EVENT  \
# 589041   SYNTHETIC DATA     364757.0    2021.0    10/31/2021
# 5539983  SYNTHETIC DATA     449747.0    2021.0    09/30/2021
# 2078086  SYNTHETIC DATA     109525.0    2021.0    09/30/2021
#
#                                        service  GEO_AREA   age  DOB  DOD  \
# 589041      Individuals_Receiving_DHS_Services       NaN  54.0  NaN  NaN
# 5539983  Individuals_Receiving_Income_Supports       NaN  51.0  NaN  NaN
# 2078086  Individuals_Receiving_Income_Supports       NaN  51.0  NaN  NaN
#
#          GENDER  GENDER_IDENTITY  SEX_ORIENT  LEGAL_SEX     RACE  \
# 589041   1~Male              NaN         NaN        NaN  1~White
# 5539983  1~Male              NaN         NaN        NaN  1~White
# 2078086  1~Male              NaN         NaN        NaN  1~White
#
#                      ETHNICITY  LIVING_ARRANGEMENT  EMPLOYMENT_STATUS  \
# 589041   2~Not Hispanic/Latinx                 NaN                NaN
# 5539983  2~Not Hispanic/Latinx                 NaN                NaN
# 2078086  2~Not Hispanic/Latinx                 NaN                NaN
#
#                  MARITAL_STATUS EDUCATION_LEVEL  VETERAN_FLAG
# 589041   1~Single-Never Married      99~Unknown           NaN
# 5539983  1~Single-Never Married      99~Unknown           NaN
# 2078086  1~Single-Never Married      99~Unknown           NaN

# %% [markdown]
#  - take a look at the record for a specific MCI_UNIQ_ID, say merchant 364757 from above result

# %%
df[df['MCI_UNIQ_ID'] == 364757]
# Out:
#          synthetic_data  MCI_UNIQ_ID  CALDR_YR DATE_OF_EVENT  \
# 589034   SYNTHETIC DATA     364757.0    2021.0    02/28/2021
# 589035   SYNTHETIC DATA     364757.0    2021.0    03/31/2021
# 589036   SYNTHETIC DATA     364757.0    2021.0    05/31/2021
# 589037   SYNTHETIC DATA     364757.0    2021.0    06/30/2021
# 589038   SYNTHETIC DATA     364757.0    2021.0    07/31/2021
# 589039   SYNTHETIC DATA     364757.0    2021.0    08/31/2021
# 589040   SYNTHETIC DATA     364757.0    2021.0    09/30/2021
# 589041   SYNTHETIC DATA     364757.0    2021.0    10/31/2021
# 589042   SYNTHETIC DATA     364757.0    2021.0    11/30/2021
# 589043   SYNTHETIC DATA     364757.0    2021.0    12/31/2021
# 4675581  SYNTHETIC DATA     364757.0    2021.0    01/31/2021
# 4675582  SYNTHETIC DATA     364757.0    2021.0    02/28/2021
# 4675583  SYNTHETIC DATA     364757.0    2021.0    03/31/2021
# 4675584  SYNTHETIC DATA     364757.0    2021.0    04/30/2021
# 4675585  SYNTHETIC DATA     364757.0    2021.0    05/31/2021
# 4675586  SYNTHETIC DATA     364757.0    2021.0    06/30/2021
# 4675587  SYNTHETIC DATA     364757.0    2021.0    07/31/2021
# 4675588  SYNTHETIC DATA     364757.0    2021.0    08/31/2021
# 4675589  SYNTHETIC DATA     364757.0    2021.0    09/30/2021
# 4675590  SYNTHETIC DATA     364757.0    2021.0    10/31/2021
# 4675591  SYNTHETIC DATA     364757.0    2021.0    11/30/2021
# 4675592  SYNTHETIC DATA     364757.0    2021.0    12/31/2021
#
#                                        service  GEO_AREA   age  DOB  DOD  \
# 589034      Individuals_Receiving_DHS_Services       NaN  54.0  NaN  NaN
# 589035      Individuals_Receiving_DHS_Services       NaN  54.0  NaN  NaN
# 589036      Individuals_Receiving_DHS_Services       NaN  54.0  NaN  NaN
# 589037      Individuals_Receiving_DHS_Services       NaN  54.0  NaN  NaN
# 589038      Individuals_Receiving_DHS_Services       NaN  54.0  NaN  NaN
# 589039      Individuals_Receiving_DHS_Services       NaN  54.0  NaN  NaN
# 589040      Individuals_Receiving_DHS_Services       NaN  54.0  NaN  NaN
# 589041      Individuals_Receiving_DHS_Services       NaN  54.0  NaN  NaN
# 589042      Individuals_Receiving_DHS_Services       NaN  54.0  NaN  NaN
# 589043      Individuals_Receiving_DHS_Services       NaN  54.0  NaN  NaN
# 4675581  Individuals_Receiving_Income_Supports       NaN  54.0  NaN  NaN
# 4675582  Individuals_Receiving_Income_Supports       NaN  54.0  NaN  NaN
# 4675583  Individuals_Receiving_Income_Supports       NaN  54.0  NaN  NaN
# 4675584  Individuals_Receiving_Income_Supports       NaN  54.0  NaN  NaN
# 4675585  Individuals_Receiving_Income_Supports       NaN  54.0  NaN  NaN
# 4675586  Individuals_Receiving_Income_Supports       NaN  54.0  NaN  NaN
# 4675587  Individuals_Receiving_Income_Supports       NaN  54.0  NaN  NaN
# 4675588  Individuals_Receiving_Income_Supports       NaN  54.0  NaN  NaN
# 4675589  Individuals_Receiving_Income_Supports       NaN  54.0  NaN  NaN
# 4675590  Individuals_Receiving_Income_Supports       NaN  54.0  NaN  NaN
# 4675591  Individuals_Receiving_Income_Supports       NaN  54.0  NaN  NaN
# 4675592  Individuals_Receiving_Income_Supports       NaN  54.0  NaN  NaN
#
#          GENDER  GENDER_IDENTITY  SEX_ORIENT  LEGAL_SEX     RACE  \
# 589034   1~Male              NaN         NaN        NaN  1~White
# 589035   1~Male              NaN         NaN        NaN  1~White
# 589036   1~Male              NaN         NaN        NaN  1~White
# 589037   1~Male              NaN         NaN        NaN  1~White
# 589038   1~Male              NaN         NaN        NaN  1~White
# 589039   1~Male              NaN         NaN        NaN  1~White
# 589040   1~Male              NaN         NaN        NaN  1~White
# 589041   1~Male              NaN         NaN        NaN  1~White
# 589042   1~Male              NaN         NaN        NaN  1~White
# 589043   1~Male              NaN         NaN        NaN  1~White
# 4675581  1~Male              NaN         NaN        NaN  1~White
# 4675582  1~Male              NaN         NaN        NaN  1~White
# 4675583  1~Male              NaN         NaN        NaN  1~White
# 4675584  1~Male              NaN         NaN        NaN  1~White
# 4675585  1~Male              NaN         NaN        NaN  1~White
# 4675586  1~Male              NaN         NaN        NaN  1~White
# 4675587  1~Male              NaN         NaN        NaN  1~White
# 4675588  1~Male              NaN         NaN        NaN  1~White
# 4675589  1~Male              NaN         NaN        NaN  1~White
# 4675590  1~Male              NaN         NaN        NaN  1~White
# 4675591  1~Male              NaN         NaN        NaN  1~White
# 4675592  1~Male              NaN         NaN        NaN  1~White
#
#                      ETHNICITY  LIVING_ARRANGEMENT  EMPLOYMENT_STATUS  \
# 589034   2~Not Hispanic/Latinx                 NaN                NaN
# 589035   2~Not Hispanic/Latinx                 NaN                NaN
# 589036   2~Not Hispanic/Latinx                 NaN                NaN
# 589037   2~Not Hispanic/Latinx                 NaN                NaN
# 589038   2~Not Hispanic/Latinx                 NaN                NaN
# 589039   2~Not Hispanic/Latinx                 NaN                NaN
# 589040   2~Not Hispanic/Latinx                 NaN                NaN
# 589041   2~Not Hispanic/Latinx                 NaN                NaN
# 589042   2~Not Hispanic/Latinx                 NaN                NaN
# 589043   2~Not Hispanic/Latinx                 NaN                NaN
# 4675581  2~Not Hispanic/Latinx                 NaN                NaN
# 4675582  2~Not Hispanic/Latinx                 NaN                NaN
# 4675583  2~Not Hispanic/Latinx                 NaN                NaN
# 4675584  2~Not Hispanic/Latinx                 NaN                NaN
# 4675585  2~Not Hispanic/Latinx                 NaN                NaN
# 4675586  2~Not Hispanic/Latinx                 NaN                NaN
# 4675587  2~Not Hispanic/Latinx                 NaN                NaN
# 4675588  2~Not Hispanic/Latinx                 NaN                NaN
# 4675589  2~Not Hispanic/Latinx                 NaN                NaN
# 4675590  2~Not Hispanic/Latinx                 NaN                NaN
# 4675591  2~Not Hispanic/Latinx                 NaN                NaN
# 4675592  2~Not Hispanic/Latinx                 NaN                NaN
#
#                  MARITAL_STATUS EDUCATION_LEVEL  VETERAN_FLAG
# 589034   1~Single-Never Married      99~Unknown           NaN
# 589035   1~Single-Never Married      99~Unknown           NaN
# 589036   1~Single-Never Married      99~Unknown           NaN
# 589037   1~Single-Never Married      99~Unknown           NaN
# 589038   1~Single-Never Married      99~Unknown           NaN
# 589039   1~Single-Never Married      99~Unknown           NaN
# 589040   1~Single-Never Married      99~Unknown           NaN
# 589041   1~Single-Never Married      99~Unknown           NaN
# 589042   1~Single-Never Married      99~Unknown           NaN
# 589043   1~Single-Never Married      99~Unknown           NaN
# 4675581  1~Single-Never Married      99~Unknown           NaN
# 4675582  1~Single-Never Married      99~Unknown           NaN
# 4675583  1~Single-Never Married      99~Unknown           NaN
# 4675584  1~Single-Never Married      99~Unknown           NaN
# 4675585  1~Single-Never Married      99~Unknown           NaN
# 4675586  1~Single-Never Married      99~Unknown           NaN
# 4675587  1~Single-Never Married      99~Unknown           NaN
# 4675588  1~Single-Never Married      99~Unknown           NaN
# 4675589  1~Single-Never Married      99~Unknown           NaN
# 4675590  1~Single-Never Married      99~Unknown           NaN
# 4675591  1~Single-Never Married      99~Unknown           NaN
# 4675592  1~Single-Never Married      99~Unknown           NaN

# %%
df[df['MCI_UNIQ_ID'] == 449747]
# Out:
#          synthetic_data  MCI_UNIQ_ID  CALDR_YR DATE_OF_EVENT  \
# 5539976  SYNTHETIC DATA     449747.0    2021.0    01/31/2021
# 5539977  SYNTHETIC DATA     449747.0    2021.0    03/31/2021
# 5539978  SYNTHETIC DATA     449747.0    2021.0    04/30/2021
# 5539979  SYNTHETIC DATA     449747.0    2021.0    05/31/2021
# 5539980  SYNTHETIC DATA     449747.0    2021.0    06/30/2021
# 5539981  SYNTHETIC DATA     449747.0    2021.0    07/31/2021
# 5539982  SYNTHETIC DATA     449747.0    2021.0    08/31/2021
# 5539983  SYNTHETIC DATA     449747.0    2021.0    09/30/2021
# 5539984  SYNTHETIC DATA     449747.0    2021.0    10/31/2021
# 5539985  SYNTHETIC DATA     449747.0    2021.0    11/30/2021
#
#                                        service  GEO_AREA   age  DOB  DOD  \
# 5539976  Individuals_Receiving_Income_Supports       NaN  51.0  NaN  NaN
# 5539977  Individuals_Receiving_Income_Supports       NaN  51.0  NaN  NaN
# 5539978  Individuals_Receiving_Income_Supports       NaN  51.0  NaN  NaN
# 5539979  Individuals_Receiving_Income_Supports       NaN  51.0  NaN  NaN
# 5539980  Individuals_Receiving_Income_Supports       NaN  51.0  NaN  NaN
# 5539981  Individuals_Receiving_Income_Supports       NaN  51.0  NaN  NaN
# 5539982  Individuals_Receiving_Income_Supports       NaN  51.0  NaN  NaN
# 5539983  Individuals_Receiving_Income_Supports       NaN  51.0  NaN  NaN
# 5539984  Individuals_Receiving_Income_Supports       NaN  51.0  NaN  NaN
# 5539985  Individuals_Receiving_Income_Supports       NaN  51.0  NaN  NaN
#
#          GENDER  GENDER_IDENTITY  SEX_ORIENT  LEGAL_SEX     RACE  \
# 5539976  1~Male              NaN         NaN        NaN  1~White
# 5539977  1~Male              NaN         NaN        NaN  1~White
# 5539978  1~Male              NaN         NaN        NaN  1~White
# 5539979  1~Male              NaN         NaN        NaN  1~White
# 5539980  1~Male              NaN         NaN        NaN  1~White
# 5539981  1~Male              NaN         NaN        NaN  1~White
# 5539982  1~Male              NaN         NaN        NaN  1~White
# 5539983  1~Male              NaN         NaN        NaN  1~White
# 5539984  1~Male              NaN         NaN        NaN  1~White
# 5539985  1~Male              NaN         NaN        NaN  1~White
#
#                      ETHNICITY  LIVING_ARRANGEMENT  EMPLOYMENT_STATUS  \
# 5539976  2~Not Hispanic/Latinx                 NaN                NaN
# 5539977  2~Not Hispanic/Latinx                 NaN                NaN
# 5539978  2~Not Hispanic/Latinx                 NaN                NaN
# 5539979  2~Not Hispanic/Latinx                 NaN                NaN
# 5539980  2~Not Hispanic/Latinx                 NaN                NaN
# 5539981  2~Not Hispanic/Latinx                 NaN                NaN
# 5539982  2~Not Hispanic/Latinx                 NaN                NaN
# 5539983  2~Not Hispanic/Latinx                 NaN                NaN
# 5539984  2~Not Hispanic/Latinx                 NaN                NaN
# 5539985  2~Not Hispanic/Latinx                 NaN                NaN
#
#                  MARITAL_STATUS EDUCATION_LEVEL  VETERAN_FLAG
# 5539976  1~Single-Never Married      99~Unknown           NaN
# 5539977  1~Single-Never Married      99~Unknown           NaN
# 5539978  1~Single-Never Married      99~Unknown           NaN
# 5539979  1~Single-Never Married      99~Unknown           NaN
# 5539980  1~Single-Never Married      99~Unknown           NaN
# 5539981  1~Single-Never Married      99~Unknown           NaN
# 5539982  1~Single-Never Married      99~Unknown           NaN
# 5539983  1~Single-Never Married      99~Unknown           NaN
# 5539984  1~Single-Never Married      99~Unknown           NaN
# 5539985  1~Single-Never Married      99~Unknown           NaN

# %% [markdown]
# ## Conduct some more data inspection at your own time

# %% [markdown]
#  - which MCI_UNIQ_ID has the highest number of records among all ID's
#  - what is the average number of interactions for clients in the file?
#  - how many months did a particular client use the service? say 449747
#  - what can you observe from the data?

# %% [markdown]
# ## gather all observations, questions, and TODOs
#
#  - columns "DATE_OF_EVENT" is string type and should be date type
#  - if we remove the last row, there would be only one value in the "synthetic_data" column, should we remove the column?
#  - MCI_UNIQ_ID column was read into dataframe as numeric, what should we read it in as?
#  - do the statistics on the columns make sense? e.g., are there any inconsistencies between age and eduction level?
#  - how many clients used the services in January? How many clients used service by each month?
#  - what is the average number of services a client use?
#  - how many clients receive services every month?
#  - do the number of services per client increase over time?

# %% [markdown]
# other data formats that we may teach, TBD

# %%
df1 = pd.read_xml("/Users/yingli/Development/TopicsInDataScience/topicsindatascience/GrantsDBExtract20240618v2.xml")
