# %% [markdown]
# ## Putting all tabula data work together

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

import dhs_util
from dhs_util import *

# %%
os.chdir('/Users/yingli/Development/TopicsInDataScience/')
df = pd.read_csv('dhs_service_records_synthesized_final.csv')

df = dhs_preprocessing(df)
df, service_map = add_service_label(df)
df = add_age_bin(df)

recipient = get_recipient_attribute(df)
retention_cohort_count, retention_cohort_ratio = get_retention_cohort(df)
df_id_serv = get_id_service_matrix(df)

# %%
sns.heatmap(retention_cohort_ratio, annot=True,
            yticklabels=pd.to_datetime(retention_cohort_ratio.index.values).month_name())
# Out:
# <Axes: xlabel='elapsed', ylabel='first_date'>

# %%
plt.figure(figsize=(15,15)) 
sns.heatmap(df_id_serv.iloc[:,1:23].corr(method="spearman"),annot=True, cmap='coolwarm')
# Out:
# <Axes: xlabel='serv', ylabel='serv'>

# %%
from mlxtend.preprocessing import *
from mlxtend.frequent_patterns import association_rules
from mlxtend.frequent_patterns import fpgrowth
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import fpmax

# %%
serv_oneHot = df_id_serv.iloc[:,1:23] > 0  # this converts value into True or False
min_freq = 1000
min_support = min_freq/serv_oneHot.shape[0]
min_confidence = 0.6
min_rule_support = 0.2
min_lift = 0.15

# %%
# Out:
#       support              itemsets
# 9    0.941422                 (S12)
# 6    0.153844                 (S09)
# 37   0.139131            (S12, S09)
# 11   0.103528                 (S14)
# 39   0.103528            (S09, S14)
# ..        ...                   ...
# 89   0.001931       (S18, S09, S11)
# 131  0.001930  (S18, S14, S09, S11)
# 110  0.001930       (S18, S14, S11)
# 75   0.001875       (S02, S09, S14)
# 27   0.001875            (S02, S14)
#
# [146 rows x 2 columns]

# %% [markdown]
# ### use mlxtend package

# %% [markdown]
# ### compute and print the association rules

# %%
def serv_rules(freq_itemsets,metrics,threshold):
    asso_rules = association_rules(freq_itemsets, metric=metrics, min_threshold=threshold)
    return asso_rules.sort_values(by='lift', ascending=False)[['antecedents', 'consequents', 'support', 'confidence', 'lift']]

def predict(antecedent, rules, consequents_only = False):
    preds = rules[rules['antecedents'] == antecedent] # get the rules for this antecedent
    if consequents_only:
        preds = preds['consequents'].apply(iter).apply(next) # a way to convert a frozen set with one element to string
    return preds

# %%
freq_itemset_apriori = apriori(serv_oneHot, use_colnames=True, min_support=min_support)\
    .sort_values(by="support", ascending=False)
freq_itemset_fpgrowth = fpgrowth(serv_oneHot,min_support=min_support,use_colnames=True)
freq_itemset_fpmax = fpmax(serv_oneHot,min_support=min_support,use_colnames=True)

rules_apriori = serv_rules(freq_itemset_apriori,"confidence",0.60)
rules_fpgrowth = serv_rules(freq_itemset_fpgrowth,"confidence",0.60)
rules_fpmax = association_rules(freq_itemset_fpmax, metric="confidence", min_threshold=0.001, support_only=True)

# %%
predict({"S09"}, rules_apriori, consequents_only=False).head()
# Out:
#   antecedents consequents   support  confidence      lift
# 1       (S09)       (S14)  0.103528    0.672938  6.500073
# 6       (S09)  (S12, S14)  0.094436    0.613843  6.500073
# 0       (S09)       (S12)  0.139131    0.904362  0.960634

# %%
predict({"S09"}, rules_fpgrowth, consequents_only=False).head()
# Out:
#    antecedents consequents   support  confidence      lift
# 14       (S09)  (S12, S14)  0.094436    0.613843  6.500073
# 8        (S09)       (S14)  0.103528    0.672938  6.500073
# 0        (S09)       (S12)  0.139131    0.904362  0.960634

# %%
predict({"S09"}, rules_fpmax, consequents_only=False).head()
# Out:
#    antecedents           consequents  antecedent support  consequent support  \
# 4        (S09)            (S02, S14)                 NaN                 NaN
# 19       (S09)       (S12, S02, S03)                 NaN                 NaN
# 25       (S09)            (S12, S10)                 NaN                 NaN
# 39       (S09)       (S12, S21, S06)                 NaN                 NaN
# 66       (S09)  (S12, S07, S14, S11)                 NaN                 NaN
#
#      support  confidence  lift  leverage  conviction  zhangs_metric
# 4   0.001875         NaN   NaN       NaN         NaN            NaN
# 19  0.002182         NaN   NaN       NaN         NaN            NaN
# 25  0.002754         NaN   NaN       NaN         NaN            NaN
# 39  0.002486         NaN   NaN       NaN         NaN            NaN
# 66  0.002055         NaN   NaN       NaN         NaN            NaN

# %% [markdown]
# * one way to verify

# %%
df[(df.serv=="S09")].merge(df[(df.serv =="S12")], on = "id").id.nunique()/df.id.nunique()
# Out:
# 0.1391310212270911

# %% [markdown]
# ### going through each service and print the rules with the service as antecedent

# %%
serv_list =  ['S'+str(i).zfill(2) for i in range(1,23)]
for i in serv_list:
    print(i)
    if (len(predict({i},rules_fpgrowth))>0):
        print(i), print(predict({i},rules_fpgrowth))
# Out:
# S01
# S02
# S02
#     antecedents consequents   support  confidence       lift
# 204       (S02)  (S12, S03)  0.003921    0.935628  76.168573
# 200       (S02)       (S03)  0.004142    0.988377  72.213908
# 201       (S02)       (S12)  0.003970    0.947251   1.006192
# S03
# S03
#    antecedents consequents   support  confidence      lift
# 16       (S03)       (S12)  0.012284    0.897482  0.953326
# S04
# S05
# S05
#     antecedents consequents   support  confidence      lift
# 175       (S05)       (S12)  0.008057    0.636996  0.676632
# S06
# S06
#     antecedents consequents   support  confidence       lift
# 115       (S06)       (S21)  0.004582    0.784477  59.162639
# S07
# S07
#     antecedents consequents   support  confidence       lift
# 141       (S07)  (S12, S11)  0.005105     0.79795  24.853835
# 137       (S07)       (S11)  0.006398     1.00000  24.460386
# 138       (S07)       (S12)  0.005105     0.79795   0.847601
# S08
# S09
# S09
#    antecedents consequents   support  confidence      lift
# 14       (S09)  (S12, S14)  0.094436    0.613843  6.500073
# 8        (S09)       (S14)  0.103528    0.672938  6.500073
# 0        (S09)       (S12)  0.139131    0.904362  0.960634
# S10
# S10
#    antecedents consequents   support  confidence      lift
# 43       (S10)       (S12)  0.005238     0.93637  0.994634
# S11
# S11
#   antecedents consequents   support  confidence      lift
# 1       (S11)       (S12)  0.032106    0.785318  0.834183
# S12
# S13
# S13
#     antecedents consequents   support  confidence      lift
# 131       (S13)  (S12, S09)  0.008153    0.684277  4.918218
# 128       (S13)       (S09)  0.008419    0.706604  4.592976
# 127       (S13)       (S12)  0.011448    0.960849  1.020636
# S14
# S14
#    antecedents consequents   support  confidence      lift
# 15       (S14)  (S12, S09)  0.094436    0.912184  6.556292
# 9        (S14)       (S09)  0.103528    1.000000  6.500073
# 10       (S14)       (S12)  0.094436    0.912184  0.968942
# S15
# S15
#    antecedents consequents   support  confidence      lift
# 32       (S15)  (S12, S09)  0.018280    0.761630  5.474191
# 29       (S15)       (S09)  0.019431    0.809554  5.262157
# 28       (S15)       (S12)  0.022561    0.939978  0.998467
# S16
# S16
#    antecedents      consequents   support  confidence      lift
# 46       (S16)            (S14)  0.009371    0.998403  9.643824
# 50       (S16)       (S09, S14)  0.009371    0.998403  9.643824
# 63       (S16)  (S12, S09, S14)  0.006815    0.726148  7.689286
# 56       (S16)       (S12, S14)  0.006815    0.726148  7.689286
# 45       (S16)            (S09)  0.009372    0.998603  6.490991
# 53       (S16)       (S12, S09)  0.006817    0.726347  5.220599
# 47       (S16)            (S12)  0.006830    0.727745  0.773027
# S17
# S17
#    antecedents consequents   support  confidence      lift
# 83       (S17)       (S12)  0.008674    0.668882  0.710502
# S18
# S18
#     antecedents      consequents   support  confidence      lift
# 181       (S18)       (S09, S14)  0.013460    0.991718  9.579254
# 177       (S18)            (S14)  0.013460    0.991718  9.579254
# 187       (S18)       (S12, S14)  0.010277    0.757212  8.018229
# 194       (S18)  (S12, S09, S14)  0.010277    0.757212  8.018229
# 176       (S18)            (S09)  0.013468    0.992271  6.449831
# 184       (S18)       (S12, S09)  0.010285    0.757764  5.446406
# 178       (S18)            (S12)  0.010384    0.765079  0.812685
# S19
# S20
# S21
# S21
#     antecedents consequents   support  confidence      lift
# 102       (S21)       (S12)  0.008848    0.667279  0.708799
# S22

# %%
rules_fpgrowth.sort_values("support",ascending=False)
# Out:
#          antecedents consequents   support  confidence      lift
# 0              (S09)       (S12)  0.139131    0.904362  0.960634
# 8              (S09)       (S14)  0.103528    0.672938  6.500073
# 9              (S14)       (S09)  0.103528    1.000000  6.500073
# 10             (S14)       (S12)  0.094436    0.912184  0.968942
# 11        (S12, S09)       (S14)  0.094436    0.678758  6.556292
# ..               ...         ...       ...         ...       ...
# 198  (S18, S09, S11)       (S14)  0.001930    0.999030  9.649879
# 199       (S18, S11)  (S09, S14)  0.001930    0.999030  9.649879
# 196       (S18, S11)       (S14)  0.001930    0.999030  9.649879
# 211       (S02, S14)       (S09)  0.001875    1.000000  6.500073
# 210       (S02, S09)       (S14)  0.001875    0.832779  8.044016
#
# [212 rows x 5 columns]

# %%
#make a scatterplot between age and number of services in the client_attributes dataset

sns.scatterplot(data = df, x = 'age', y = 'race', s = 2)
plt.title('Age vs Number of Services')
plt.xlabel('Age')
plt.ylabel('Number of Services')
plt.show()

# %%
import itertools
j = 0
for i in itertools.combinations(df.service.unique(),2):
    j=j+1
    print(j), print(i)
# Out:
# 1
# ('Children_Attending_Early_Childhood_Programs_Managed_by_DHS', 'Children_in_Care')
# 2
# ('Children_Attending_Early_Childhood_Programs_Managed_by_DHS', 'Children_Receiving_Child_Welfare_Services')
# 3
# ('Children_Attending_Early_Childhood_Programs_Managed_by_DHS', 'Children_Receiving_DHS_Funded_Out_of_School_Programs')
# 4
# ('Children_Attending_Early_Childhood_Programs_Managed_by_DHS', 'Children_Receiving_Early_Intervention_Services')
# 5
# ('Children_Attending_Early_Childhood_Programs_Managed_by_DHS', 'Families_Receiving_Child_Welfare_Services')
# 6
# ('Children_Attending_Early_Childhood_Programs_Managed_by_DHS', 'Homeless_Population')
# 7
# ('Children_Attending_Early_Childhood_Programs_Managed_by_DHS', 'Homicides')
# 8
# ('Children_Attending_Early_Childhood_Programs_Managed_by_DHS', 'Individuals_Receiving_DHS_Services')
# 9
# ('Children_Attending_Early_Childhood_Programs_Managed_by_DHS', 'Individuals_Receiving_Family_Strengthening_Programs')
# 10
# ('Children_Attending_Early_Childhood_Programs_Managed_by_DHS', 'Individuals_Receiving_Homelessness_and_Housing_Services')
# 11
# ('Children_Attending_Early_Childhood_Programs_Managed_by_DHS', 'Individuals_Receiving_Income_Supports')
# 12
# ('Children_Attending_Early_Childhood_Programs_Managed_by_DHS', 'Individuals_Receiving_Intellectual_Disability_Services')
# 13
# ('Children_Attending_Early_Childhood_Programs_Managed_by_DHS', 'Individuals_Receiving_Mental_Health_Services')
# 14
# ('Children_Attending_Early_Childhood_Programs_Managed_by_DHS', 'Individuals_Receiving_Substance_Use_Disorder_Services')
# 15
# ('Children_Attending_Early_Childhood_Programs_Managed_by_DHS', 'Involuntary_Commitments')
# 16
# ('Children_Attending_Early_Childhood_Programs_Managed_by_DHS', 'Jail_Population')
# 17
# ('Children_Attending_Early_Childhood_Programs_Managed_by_DHS', 'Mental_Health_Crises')
# 18
# ('Children_Attending_Early_Childhood_Programs_Managed_by_DHS', 'Older_Adults_Receiving_Services')
# 19
# ('Children_Attending_Early_Childhood_Programs_Managed_by_DHS', 'Overdoses')
# 20
# ('Children_Attending_Early_Childhood_Programs_Managed_by_DHS', 'Parents_Receiving_Child_Welfare_Services')
# 21
# ('Children_Attending_Early_Childhood_Programs_Managed_by_DHS', 'Suicides')
# 22
# ('Children_in_Care', 'Children_Receiving_Child_Welfare_Services')
# 23
# ('Children_in_Care', 'Children_Receiving_DHS_Funded_Out_of_School_Programs')
# 24
# ('Children_in_Care', 'Children_Receiving_Early_Intervention_Services')
# 25
# ('Children_in_Care', 'Families_Receiving_Child_Welfare_Services')
# 26
# ('Children_in_Care', 'Homeless_Population')
# 27
# ('Children_in_Care', 'Homicides')
# 28
# ('Children_in_Care', 'Individuals_Receiving_DHS_Services')
# 29
# ('Children_in_Care', 'Individuals_Receiving_Family_Strengthening_Programs')
# 30
# ('Children_in_Care', 'Individuals_Receiving_Homelessness_and_Housing_Services')
# 31
# ('Children_in_Care', 'Individuals_Receiving_Income_Supports')
# 32
# ('Children_in_Care', 'Individuals_Receiving_Intellectual_Disability_Services')
# 33
# ('Children_in_Care', 'Individuals_Receiving_Mental_Health_Services')
# 34
# ('Children_in_Care', 'Individuals_Receiving_Substance_Use_Disorder_Services')
# 35
# ('Children_in_Care', 'Involuntary_Commitments')
# 36
# ('Children_in_Care', 'Jail_Population')
# 37
# ('Children_in_Care', 'Mental_Health_Crises')
# 38
# ('Children_in_Care', 'Older_Adults_Receiving_Services')
# 39
# ('Children_in_Care', 'Overdoses')
# 40
# ('Children_in_Care', 'Parents_Receiving_Child_Welfare_Services')
# 41
# ('Children_in_Care', 'Suicides')
# 42
# ('Children_Receiving_Child_Welfare_Services', 'Children_Receiving_DHS_Funded_Out_of_School_Programs')
# 43
# ('Children_Receiving_Child_Welfare_Services', 'Children_Receiving_Early_Intervention_Services')
# 44
# ('Children_Receiving_Child_Welfare_Services', 'Families_Receiving_Child_Welfare_Services')
# 45
# ('Children_Receiving_Child_Welfare_Services', 'Homeless_Population')
# 46
# ('Children_Receiving_Child_Welfare_Services', 'Homicides')
# 47
# ('Children_Receiving_Child_Welfare_Services', 'Individuals_Receiving_DHS_Services')
# 48
# ('Children_Receiving_Child_Welfare_Services', 'Individuals_Receiving_Family_Strengthening_Programs')
# 49
# ('Children_Receiving_Child_Welfare_Services', 'Individuals_Receiving_Homelessness_and_Housing_Services')
# 50
# ('Children_Receiving_Child_Welfare_Services', 'Individuals_Receiving_Income_Supports')
# 51
# ('Children_Receiving_Child_Welfare_Services', 'Individuals_Receiving_Intellectual_Disability_Services')
# 52
# ('Children_Receiving_Child_Welfare_Services', 'Individuals_Receiving_Mental_Health_Services')
# 53
# ('Children_Receiving_Child_Welfare_Services', 'Individuals_Receiving_Substance_Use_Disorder_Services')
# 54
# ('Children_Receiving_Child_Welfare_Services', 'Involuntary_Commitments')
# 55
# ('Children_Receiving_Child_Welfare_Services', 'Jail_Population')
# 56
# ('Children_Receiving_Child_Welfare_Services', 'Mental_Health_Crises')
# 57
# ('Children_Receiving_Child_Welfare_Services', 'Older_Adults_Receiving_Services')
# 58
# ('Children_Receiving_Child_Welfare_Services', 'Overdoses')
# 59
# ('Children_Receiving_Child_Welfare_Services', 'Parents_Receiving_Child_Welfare_Services')
# 60
# ('Children_Receiving_Child_Welfare_Services', 'Suicides')
# 61
# ('Children_Receiving_DHS_Funded_Out_of_School_Programs', 'Children_Receiving_Early_Intervention_Services')
# 62
# ('Children_Receiving_DHS_Funded_Out_of_School_Programs', 'Families_Receiving_Child_Welfare_Services')
# 63
# ('Children_Receiving_DHS_Funded_Out_of_School_Programs', 'Homeless_Population')
# 64
# ('Children_Receiving_DHS_Funded_Out_of_School_Programs', 'Homicides')
# 65
# ('Children_Receiving_DHS_Funded_Out_of_School_Programs', 'Individuals_Receiving_DHS_Services')
# 66
# ('Children_Receiving_DHS_Funded_Out_of_School_Programs', 'Individuals_Receiving_Family_Strengthening_Programs')
# 67
# ('Children_Receiving_DHS_Funded_Out_of_School_Programs', 'Individuals_Receiving_Homelessness_and_Housing_Services')
# 68
# ('Children_Receiving_DHS_Funded_Out_of_School_Programs', 'Individuals_Receiving_Income_Supports')
# 69
# ('Children_Receiving_DHS_Funded_Out_of_School_Programs', 'Individuals_Receiving_Intellectual_Disability_Services')
# 70
# ('Children_Receiving_DHS_Funded_Out_of_School_Programs', 'Individuals_Receiving_Mental_Health_Services')
# 71
# ('Children_Receiving_DHS_Funded_Out_of_School_Programs', 'Individuals_Receiving_Substance_Use_Disorder_Services')
# 72
# ('Children_Receiving_DHS_Funded_Out_of_School_Programs', 'Involuntary_Commitments')
# 73
# ('Children_Receiving_DHS_Funded_Out_of_School_Programs', 'Jail_Population')
# 74
# ('Children_Receiving_DHS_Funded_Out_of_School_Programs', 'Mental_Health_Crises')
# 75
# ('Children_Receiving_DHS_Funded_Out_of_School_Programs', 'Older_Adults_Receiving_Services')
# 76
# ('Children_Receiving_DHS_Funded_Out_of_School_Programs', 'Overdoses')
# 77
# ('Children_Receiving_DHS_Funded_Out_of_School_Programs', 'Parents_Receiving_Child_Welfare_Services')
# 78
# ('Children_Receiving_DHS_Funded_Out_of_School_Programs', 'Suicides')
# 79
# ('Children_Receiving_Early_Intervention_Services', 'Families_Receiving_Child_Welfare_Services')
# 80
# ('Children_Receiving_Early_Intervention_Services', 'Homeless_Population')
# 81
# ('Children_Receiving_Early_Intervention_Services', 'Homicides')
# 82
# ('Children_Receiving_Early_Intervention_Services', 'Individuals_Receiving_DHS_Services')
# 83
# ('Children_Receiving_Early_Intervention_Services', 'Individuals_Receiving_Family_Strengthening_Programs')
# 84
# ('Children_Receiving_Early_Intervention_Services', 'Individuals_Receiving_Homelessness_and_Housing_Services')
# 85
# ('Children_Receiving_Early_Intervention_Services', 'Individuals_Receiving_Income_Supports')
# 86
# ('Children_Receiving_Early_Intervention_Services', 'Individuals_Receiving_Intellectual_Disability_Services')
# 87
# ('Children_Receiving_Early_Intervention_Services', 'Individuals_Receiving_Mental_Health_Services')
# 88
# ('Children_Receiving_Early_Intervention_Services', 'Individuals_Receiving_Substance_Use_Disorder_Services')
# 89
# ('Children_Receiving_Early_Intervention_Services', 'Involuntary_Commitments')
# 90
# ('Children_Receiving_Early_Intervention_Services', 'Jail_Population')
# 91
# ('Children_Receiving_Early_Intervention_Services', 'Mental_Health_Crises')
# 92
# ('Children_Receiving_Early_Intervention_Services', 'Older_Adults_Receiving_Services')
# 93
# ('Children_Receiving_Early_Intervention_Services', 'Overdoses')
# 94
# ('Children_Receiving_Early_Intervention_Services', 'Parents_Receiving_Child_Welfare_Services')
# 95
# ('Children_Receiving_Early_Intervention_Services', 'Suicides')
# 96
# ('Families_Receiving_Child_Welfare_Services', 'Homeless_Population')
# 97
# ('Families_Receiving_Child_Welfare_Services', 'Homicides')
# 98
# ('Families_Receiving_Child_Welfare_Services', 'Individuals_Receiving_DHS_Services')
# 99
# ('Families_Receiving_Child_Welfare_Services', 'Individuals_Receiving_Family_Strengthening_Programs')
# 100
# ('Families_Receiving_Child_Welfare_Services', 'Individuals_Receiving_Homelessness_and_Housing_Services')
# 101
# ('Families_Receiving_Child_Welfare_Services', 'Individuals_Receiving_Income_Supports')
# 102
# ('Families_Receiving_Child_Welfare_Services', 'Individuals_Receiving_Intellectual_Disability_Services')
# 103
# ('Families_Receiving_Child_Welfare_Services', 'Individuals_Receiving_Mental_Health_Services')
# 104
# ('Families_Receiving_Child_Welfare_Services', 'Individuals_Receiving_Substance_Use_Disorder_Services')
# 105
# ('Families_Receiving_Child_Welfare_Services', 'Involuntary_Commitments')
# 106
# ('Families_Receiving_Child_Welfare_Services', 'Jail_Population')
# 107
# ('Families_Receiving_Child_Welfare_Services', 'Mental_Health_Crises')
# 108
# ('Families_Receiving_Child_Welfare_Services', 'Older_Adults_Receiving_Services')
# 109
# ('Families_Receiving_Child_Welfare_Services', 'Overdoses')
# 110
# ('Families_Receiving_Child_Welfare_Services', 'Parents_Receiving_Child_Welfare_Services')
# 111
# ('Families_Receiving_Child_Welfare_Services', 'Suicides')
# 112
# ('Homeless_Population', 'Homicides')
# 113
# ('Homeless_Population', 'Individuals_Receiving_DHS_Services')
# 114
# ('Homeless_Population', 'Individuals_Receiving_Family_Strengthening_Programs')
# 115
# ('Homeless_Population', 'Individuals_Receiving_Homelessness_and_Housing_Services')
# 116
# ('Homeless_Population', 'Individuals_Receiving_Income_Supports')
# 117
# ('Homeless_Population', 'Individuals_Receiving_Intellectual_Disability_Services')
# 118
# ('Homeless_Population', 'Individuals_Receiving_Mental_Health_Services')
# 119
# ('Homeless_Population', 'Individuals_Receiving_Substance_Use_Disorder_Services')
# 120
# ('Homeless_Population', 'Involuntary_Commitments')
# 121
# ('Homeless_Population', 'Jail_Population')
# 122
# ('Homeless_Population', 'Mental_Health_Crises')
# 123
# ('Homeless_Population', 'Older_Adults_Receiving_Services')
# 124
# ('Homeless_Population', 'Overdoses')
# 125
# ('Homeless_Population', 'Parents_Receiving_Child_Welfare_Services')
# 126
# ('Homeless_Population', 'Suicides')
# 127
# ('Homicides', 'Individuals_Receiving_DHS_Services')
# 128
# ('Homicides', 'Individuals_Receiving_Family_Strengthening_Programs')
# 129
# ('Homicides', 'Individuals_Receiving_Homelessness_and_Housing_Services')
# 130
# ('Homicides', 'Individuals_Receiving_Income_Supports')
# 131
# ('Homicides', 'Individuals_Receiving_Intellectual_Disability_Services')
# 132
# ('Homicides', 'Individuals_Receiving_Mental_Health_Services')
# 133
# ('Homicides', 'Individuals_Receiving_Substance_Use_Disorder_Services')
# 134
# ('Homicides', 'Involuntary_Commitments')
# 135
# ('Homicides', 'Jail_Population')
# 136
# ('Homicides', 'Mental_Health_Crises')
# 137
# ('Homicides', 'Older_Adults_Receiving_Services')
# 138
# ('Homicides', 'Overdoses')
# 139
# ('Homicides', 'Parents_Receiving_Child_Welfare_Services')
# 140
# ('Homicides', 'Suicides')
# 141
# ('Individuals_Receiving_DHS_Services', 'Individuals_Receiving_Family_Strengthening_Programs')
# 142
# ('Individuals_Receiving_DHS_Services', 'Individuals_Receiving_Homelessness_and_Housing_Services')
# 143
# ('Individuals_Receiving_DHS_Services', 'Individuals_Receiving_Income_Supports')
# 144
# ('Individuals_Receiving_DHS_Services', 'Individuals_Receiving_Intellectual_Disability_Services')
# 145
# ('Individuals_Receiving_DHS_Services', 'Individuals_Receiving_Mental_Health_Services')
# 146
# ('Individuals_Receiving_DHS_Services', 'Individuals_Receiving_Substance_Use_Disorder_Services')
# 147
# ('Individuals_Receiving_DHS_Services', 'Involuntary_Commitments')
# 148
# ('Individuals_Receiving_DHS_Services', 'Jail_Population')
# 149
# ('Individuals_Receiving_DHS_Services', 'Mental_Health_Crises')
# 150
# ('Individuals_Receiving_DHS_Services', 'Older_Adults_Receiving_Services')
# 151
# ('Individuals_Receiving_DHS_Services', 'Overdoses')
# 152
# ('Individuals_Receiving_DHS_Services', 'Parents_Receiving_Child_Welfare_Services')
# 153
# ('Individuals_Receiving_DHS_Services', 'Suicides')
# 154
# ('Individuals_Receiving_Family_Strengthening_Programs', 'Individuals_Receiving_Homelessness_and_Housing_Services')
# 155
# ('Individuals_Receiving_Family_Strengthening_Programs', 'Individuals_Receiving_Income_Supports')
# 156
# ('Individuals_Receiving_Family_Strengthening_Programs', 'Individuals_Receiving_Intellectual_Disability_Services')
# 157
# ('Individuals_Receiving_Family_Strengthening_Programs', 'Individuals_Receiving_Mental_Health_Services')
# 158
# ('Individuals_Receiving_Family_Strengthening_Programs', 'Individuals_Receiving_Substance_Use_Disorder_Services')
# 159
# ('Individuals_Receiving_Family_Strengthening_Programs', 'Involuntary_Commitments')
# 160
# ('Individuals_Receiving_Family_Strengthening_Programs', 'Jail_Population')
# 161
# ('Individuals_Receiving_Family_Strengthening_Programs', 'Mental_Health_Crises')
# 162
# ('Individuals_Receiving_Family_Strengthening_Programs', 'Older_Adults_Receiving_Services')
# 163
# ('Individuals_Receiving_Family_Strengthening_Programs', 'Overdoses')
# 164
# ('Individuals_Receiving_Family_Strengthening_Programs', 'Parents_Receiving_Child_Welfare_Services')
# 165
# ('Individuals_Receiving_Family_Strengthening_Programs', 'Suicides')
# 166
# ('Individuals_Receiving_Homelessness_and_Housing_Services', 'Individuals_Receiving_Income_Supports')
# 167
# ('Individuals_Receiving_Homelessness_and_Housing_Services', 'Individuals_Receiving_Intellectual_Disability_Services')
# 168
# ('Individuals_Receiving_Homelessness_and_Housing_Services', 'Individuals_Receiving_Mental_Health_Services')
# 169
# ('Individuals_Receiving_Homelessness_and_Housing_Services', 'Individuals_Receiving_Substance_Use_Disorder_Services')
# 170
# ('Individuals_Receiving_Homelessness_and_Housing_Services', 'Involuntary_Commitments')
# 171
# ('Individuals_Receiving_Homelessness_and_Housing_Services', 'Jail_Population')
# 172
# ('Individuals_Receiving_Homelessness_and_Housing_Services', 'Mental_Health_Crises')
# 173
# ('Individuals_Receiving_Homelessness_and_Housing_Services', 'Older_Adults_Receiving_Services')
# 174
# ('Individuals_Receiving_Homelessness_and_Housing_Services', 'Overdoses')
# 175
# ('Individuals_Receiving_Homelessness_and_Housing_Services', 'Parents_Receiving_Child_Welfare_Services')
# 176
# ('Individuals_Receiving_Homelessness_and_Housing_Services', 'Suicides')
# 177
# ('Individuals_Receiving_Income_Supports', 'Individuals_Receiving_Intellectual_Disability_Services')
# 178
# ('Individuals_Receiving_Income_Supports', 'Individuals_Receiving_Mental_Health_Services')
# 179
# ('Individuals_Receiving_Income_Supports', 'Individuals_Receiving_Substance_Use_Disorder_Services')
# 180
# ('Individuals_Receiving_Income_Supports', 'Involuntary_Commitments')
# 181
# ('Individuals_Receiving_Income_Supports', 'Jail_Population')
# 182
# ('Individuals_Receiving_Income_Supports', 'Mental_Health_Crises')
# 183
# ('Individuals_Receiving_Income_Supports', 'Older_Adults_Receiving_Services')
# 184
# ('Individuals_Receiving_Income_Supports', 'Overdoses')
# 185
# ('Individuals_Receiving_Income_Supports', 'Parents_Receiving_Child_Welfare_Services')
# 186
# ('Individuals_Receiving_Income_Supports', 'Suicides')
# 187
# ('Individuals_Receiving_Intellectual_Disability_Services', 'Individuals_Receiving_Mental_Health_Services')
# 188
# ('Individuals_Receiving_Intellectual_Disability_Services', 'Individuals_Receiving_Substance_Use_Disorder_Services')
# 189
# ('Individuals_Receiving_Intellectual_Disability_Services', 'Involuntary_Commitments')
# 190
# ('Individuals_Receiving_Intellectual_Disability_Services', 'Jail_Population')
# 191
# ('Individuals_Receiving_Intellectual_Disability_Services', 'Mental_Health_Crises')
# 192
# ('Individuals_Receiving_Intellectual_Disability_Services', 'Older_Adults_Receiving_Services')
# 193
# ('Individuals_Receiving_Intellectual_Disability_Services', 'Overdoses')
# 194
# ('Individuals_Receiving_Intellectual_Disability_Services', 'Parents_Receiving_Child_Welfare_Services')
# 195
# ('Individuals_Receiving_Intellectual_Disability_Services', 'Suicides')
# 196
# ('Individuals_Receiving_Mental_Health_Services', 'Individuals_Receiving_Substance_Use_Disorder_Services')
# 197
# ('Individuals_Receiving_Mental_Health_Services', 'Involuntary_Commitments')
# 198
# ('Individuals_Receiving_Mental_Health_Services', 'Jail_Population')
# 199
# ('Individuals_Receiving_Mental_Health_Services', 'Mental_Health_Crises')
# 200
# ('Individuals_Receiving_Mental_Health_Services', 'Older_Adults_Receiving_Services')
# 201
# ('Individuals_Receiving_Mental_Health_Services', 'Overdoses')
# 202
# ('Individuals_Receiving_Mental_Health_Services', 'Parents_Receiving_Child_Welfare_Services')
# 203
# ('Individuals_Receiving_Mental_Health_Services', 'Suicides')
# 204
# ('Individuals_Receiving_Substance_Use_Disorder_Services', 'Involuntary_Commitments')
# 205
# ('Individuals_Receiving_Substance_Use_Disorder_Services', 'Jail_Population')
# 206
# ('Individuals_Receiving_Substance_Use_Disorder_Services', 'Mental_Health_Crises')
# 207
# ('Individuals_Receiving_Substance_Use_Disorder_Services', 'Older_Adults_Receiving_Services')
# 208
# ('Individuals_Receiving_Substance_Use_Disorder_Services', 'Overdoses')
# 209
# ('Individuals_Receiving_Substance_Use_Disorder_Services', 'Parents_Receiving_Child_Welfare_Services')
# 210
# ('Individuals_Receiving_Substance_Use_Disorder_Services', 'Suicides')
# 211
# ('Involuntary_Commitments', 'Jail_Population')
# 212
# ('Involuntary_Commitments', 'Mental_Health_Crises')
# 213
# ('Involuntary_Commitments', 'Older_Adults_Receiving_Services')
# 214
# ('Involuntary_Commitments', 'Overdoses')
# 215
# ('Involuntary_Commitments', 'Parents_Receiving_Child_Welfare_Services')
# 216
# ('Involuntary_Commitments', 'Suicides')
# 217
# ('Jail_Population', 'Mental_Health_Crises')
# 218
# ('Jail_Population', 'Older_Adults_Receiving_Services')
# 219
# ('Jail_Population', 'Overdoses')
# 220
# ('Jail_Population', 'Parents_Receiving_Child_Welfare_Services')
# 221
# ('Jail_Population', 'Suicides')
# 222
# ('Mental_Health_Crises', 'Older_Adults_Receiving_Services')
# 223
# ('Mental_Health_Crises', 'Overdoses')
# 224
# ('Mental_Health_Crises', 'Parents_Receiving_Child_Welfare_Services')
# 225
# ('Mental_Health_Crises', 'Suicides')
# 226
# ('Older_Adults_Receiving_Services', 'Overdoses')
# 227
# ('Older_Adults_Receiving_Services', 'Parents_Receiving_Child_Welfare_Services')
# 228
# ('Older_Adults_Receiving_Services', 'Suicides')
# 229
# ('Overdoses', 'Parents_Receiving_Child_Welfare_Services')
# 230
# ('Overdoses', 'Suicides')
# 231
# ('Parents_Receiving_Child_Welfare_Services', 'Suicides')
