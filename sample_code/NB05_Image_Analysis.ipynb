# %% [markdown]
# # Image Analysis
#
# tentative plan for this section:
# - introduce the process of making a dataset for images
# - labeling for the task
# - discuss the ideas of image segmentation, object detection and image recognition
