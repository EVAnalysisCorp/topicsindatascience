# %% [markdown]
# ### spatial and temporal resolutions

# %%
import pandas as pd
import numpy as np
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime, timedelta
import folium
import os

import skmob
from skmob.preprocessing import compression, detection, clustering
from skmob.tessellation import tilers
from skmob.preprocessing import filtering
from skmob.utils import plot


import math
import branca.colormap as cm


pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 200)
import warnings
warnings.simplefilter("ignore")

# %% [markdown]
# ### read data, clean dat, adding auxiliary columns
#  - use local time zone

# %%
os.chdir('/Users/yingli/Development/TopicsInDataScience/')
events = pd.read_csv("Galapagos Tortoise Movement Ecology Programme_2009-2018.csv", sep=',', parse_dates=[2])
new_cols = pd.Series(events.columns.values).str.replace(pat = r"[-:]", repl="_", regex=True)
tortoise = events.set_axis(labels = new_cols, axis =1)
tortoise.drop(tortoise.index[tortoise["manually_marked_outlier"].notna()], inplace = True)
tortoise.drop(columns =["manually_marked_outlier"], inplace=True)
tortoise.drop(index = tortoise.index[tortoise.isna().any(axis=1)], inplace=True)
cols = ['event_id', 'timestamp', 'location_long', 'location_lat',
       'eobs_temperature', 'ground_speed', 'heading', 'height_above_ellipsoid',
       #'individual_taxon_canonical_name', 'tag_local_identifier',
       'individual_local_identifier']
tortoise = tortoise[cols].assign()
tortoise.insert(loc = 2, column = "timestamp_UTC",
    value = tortoise['timestamp'].apply(lambda x: x.tz_localize(tz='UTC'))
)
tortoise.insert(loc = 3, column = "timestamp_local", 
    value = tortoise["timestamp_UTC"].apply(lambda x: x.tz_convert(tz='US/Pacific'))
)

tortoise.sort_values(by = ["individual_local_identifier", "timestamp_local"], inplace=True)

tortoise.insert(loc = 4, column = "minute_diff", 
    value = tortoise.groupby(['individual_local_identifier'])["timestamp_local"].diff()\
        .apply(lambda x: x/np.timedelta64(1, 'm')).fillna(0).astype('int64')
)

tortoise['year'] = tortoise["timestamp_local"].dt.year
tortoise['month'] = tortoise["timestamp_local"].dt.month
tortoise['date'] = tortoise["timestamp_local"].dt.date

# %%
from tesspy import Tessellation
tessellation= Tessellation('isla santa cruz').hexagons(resolution=8)
#tessellation = ffm_hex_8
tessellation.rename(columns={'hex_id': "tile_ID"} , inplace=True)
#tessellation['tile_ID']= tessellation['tile_ID'].apply(lambda x: int(x,16))
tessellation["tile_lng"] = tessellation.geometry.centroid.x
tessellation["tile_lat"] = tessellation.geometry.centroid.y

# %% [raw]
# tessellation = tilers.tiler.get("squared", base_shape="isla santa cruz", meters=100)
# tessellation["tile_lng"] = tessellation.geometry.centroid.x
# tessellation["tile_lat"] = tessellation.geometry.centroid.y

# %% [raw]
# tortoise_trajectory = skmob.TrajDataFrame(tortoise, latitude='location_lat', longitude='location_long', \
#     user_id='individual_local_identifier', datetime='timestamp_local', \
# )
# tortoise_trajectory_mapping = tortoise_trajectory.mapping(tessellation, remove_na = True) # map trajectory into tessellation tiles
# tortoise_tiled = tortoise_trajectory_mapping.merge(tessellation, on = "tile_ID") # join to get the tile coordinates
# tortoise_tiled.sort_values(by = ["uid", "datetime"], inplace=True) # sort before making trajectory

# %%
tortoise_trajectory = skmob.TrajDataFrame(tortoise, latitude='location_lat', longitude='location_long', \
    user_id='individual_local_identifier', datetime='timestamp_local', \
)
tortoise_trajectory_mapping = tortoise_trajectory.mapping(tessellation,remove_na =True) # map trajectory into tessellation tiles
tortoise_tiled = tortoise_trajectory_mapping.merge(tessellation, on = "tile_ID") # join to get the tile coordinates
tortoise_tiled.drop(columns =["lat","lng"], inplace=True) # drop the original lat/lng so that we can create new trajectory
tortoise_tiled.sort_values(by = ["uid", "datetime"], inplace=True) # sort before making trajectory
tortoise_tiled_trajectory = skmob.TrajDataFrame(tortoise_tiled, latitude='tile_lat', longitude='tile_lng', \
    user_id='uid', datetime='datetime', \
)
tortoise_trajectory_compressed = compression.compress(tortoise_trajectory, spatial_radius_km=0.02) # compressed trajectory
tortoise_tiled_trajectory_compressed = compression.compress(tortoise_tiled_trajectory, spatial_radius_km=0.02) # compressed trajectory

# %%
alison = tortoise[tortoise["individual_local_identifier"] == "Alison"]
alison_trajectory = tortoise_trajectory.query("uid == 'Alison'")
alison_trajectory_mapping = tortoise_trajectory_mapping.query("uid == 'Alison'")
alison_tiled = tortoise_tiled.query("uid == 'Alison'")
alison_tiled_trajectory = tortoise_tiled_trajectory.query("uid == 'Alison'")
alison_trajectory_compressed = tortoise_trajectory_compressed.query("uid == 'Alison'")
alison_tiled_trajectory_compressed = tortoise_tiled_trajectory_compressed.query("uid == 'Alison'")
#alison.shape, alison_trajectory.shape, alison_trajectory_mapping.shape, alison_tiled_trajectory.shape, alison_trajectory_compressed.shape, alison_tiled_trajectory_compressed.shape

# %% [markdown]
# ### work on Alison

# %%
temp_df = alison_trajectory_mapping['tile_ID'].value_counts()
alison_tiled_count = pd.DataFrame({'tile_ID': temp_df.index, 'count': temp_df.values})
alison_tiled_count.set_index("tile_ID",inplace=True)
tessellation_count = tessellation.set_index('tile_ID')
tessellation_count = tessellation_count.merge(alison_tiled_count, on = "tile_ID")

# %%
center = [(tessellation_count["geometry"].centroid.y.min() + tessellation_count["geometry"].centroid.y.max())/2, \
        (tessellation_count["geometry"].centroid.x.min() + tessellation_count["geometry"].centroid.x.max())/2]
linear_color = cm.LinearColormap(['green', 'yellow', 'red'], vmin=0, vmax=math.log(tessellation_count["count"].max()))
f = folium.Figure(width=1000, height=500)
m = folium.Map(location=center, zoom_start=14, min_zoom=2, max_bounds=True, tiles='cartodbpositron').add_to(f)
folium.GeoJson(tessellation_count, style_function=lambda feature: {
        'fill': True,
        'color': 'darkgrey' if feature['properties']['count']==0 else \
                linear_color(math.log(float(feature['properties']['count']))),
        'weight' : 0.3,
        'fillOpacity' : 0.5,
        'label': "tile_ID"
        }).add_to(m)
m
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9639741d8f339970a416bc7c6c0563eb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9639741d8f339970a416bc7c6c0563eb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9639741d8f339970a416bc7c6c0563eb = L.map(
#                 &quot;map_9639741d8f339970a416bc7c6c0563eb&quot;,
#                 {
#                     center: [-0.6441288001387161, -90.25832264364391],
#                     crs: L.CRS.EPSG3857,
#                     maxBounds: [[-90, -180], [90, 180]],
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bef35c65fd34cddff8668088f85bfb97 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 2, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_bef35c65fd34cddff8668088f85bfb97.addTo(map_9639741d8f339970a416bc7c6c0563eb);
#
#
#         function geo_json_c7e17a885f6f6c70e6544e9b0ffe8697_styler(feature) {
#             switch(feature.id) {
#                 case &quot;886c597961fffff&quot;:
#                     return {&quot;color&quot;: &quot;#ff7000ff&quot;, &quot;fill&quot;: true, &quot;fillOpacity&quot;: 0.5, &quot;label&quot;: &quot;tile_ID&quot;, &quot;weight&quot;: 0.3};
#                 case &quot;886c5bb657fffff&quot;:
#                     return {&quot;color&quot;: &quot;#ff8200ff&quot;, &quot;fill&quot;: true, &quot;fillOpacity&quot;: 0.5, &quot;label&quot;: &quot;tile_ID&quot;, &quot;weight&quot;: 0.3};
#                 case &quot;886c597965fffff&quot;:
#                     return {&quot;color&quot;: &quot;#89c500ff&quot;, &quot;fill&quot;: true, &quot;fillOpacity&quot;: 0.5, &quot;label&quot;: &quot;tile_ID&quot;, &quot;weight&quot;: 0.3};
#                 case &quot;886c594cb7fffff&quot;:
#                     return {&quot;color&quot;: &quot;#ffff00ff&quot;, &quot;fill&quot;: true, &quot;fillOpacity&quot;: 0.5, &quot;label&quot;: &quot;tile_ID&quot;, &quot;weight&quot;: 0.3};
#                 case &quot;886c5bb655fffff&quot;:
#                     return {&quot;color&quot;: &quot;#ffa300ff&quot;, &quot;fill&quot;: true, &quot;fillOpacity&quot;: 0.5, &quot;label&quot;: &quot;tile_ID&quot;, &quot;weight&quot;: 0.3};
#                 case &quot;886c597969fffff&quot;:
#                     return {&quot;color&quot;: &quot;#ff0000ff&quot;, &quot;fill&quot;: true, &quot;fillOpacity&quot;: 0.5, &quot;label&quot;: &quot;tile_ID&quot;, &quot;weight&quot;: 0.3};
#                 case &quot;886c59796dfffff&quot;:
#                     return {&quot;color&quot;: &quot;#ff7300ff&quot;, &quot;fill&quot;: true, &quot;fillOpacity&quot;: 0.5, &quot;label&quot;: &quot;tile_ID&quot;, &quot;weight&quot;: 0.3};
#                 case &quot;886c594cb3fffff&quot;:
#                     return {&quot;color&quot;: &quot;#ff9600ff&quot;, &quot;fill&quot;: true, &quot;fillOpacity&quot;: 0.5, &quot;label&quot;: &quot;tile_ID&quot;, &quot;weight&quot;: 0.3};
#                 case &quot;886c5bb659fffff&quot;:
#                     return {&quot;color&quot;: &quot;#ffa600ff&quot;, &quot;fill&quot;: true, &quot;fillOpacity&quot;: 0.5, &quot;label&quot;: &quot;tile_ID&quot;, &quot;weight&quot;: 0.3};
#                 case &quot;886c5bb651fffff&quot;:
#                     return {&quot;color&quot;: &quot;#ff4f00ff&quot;, &quot;fill&quot;: true, &quot;fillOpacity&quot;: 0.5, &quot;label&quot;: &quot;tile_ID&quot;, &quot;weight&quot;: 0.3};
#                 case &quot;886c59796bfffff&quot;:
#                     return {&quot;color&quot;: &quot;#ff8100ff&quot;, &quot;fill&quot;: true, &quot;fillOpacity&quot;: 0.5, &quot;label&quot;: &quot;tile_ID&quot;, &quot;weight&quot;: 0.3};
#                 default:
#                     return {&quot;color&quot;: &quot;#ffea00ff&quot;, &quot;fill&quot;: true, &quot;fillOpacity&quot;: 0.5, &quot;label&quot;: &quot;tile_ID&quot;, &quot;weight&quot;: 0.3};
#             }
#         }
#
#         function geo_json_c7e17a885f6f6c70e6544e9b0ffe8697_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_c7e17a885f6f6c70e6544e9b0ffe8697 = L.geoJson(null, {
#                 onEachFeature: geo_json_c7e17a885f6f6c70e6544e9b0ffe8697_onEachFeature,
#
#                 style: geo_json_c7e17a885f6f6c70e6544e9b0ffe8697_styler,
#         });
#
#         function geo_json_c7e17a885f6f6c70e6544e9b0ffe8697_add (data) {
#             geo_json_c7e17a885f6f6c70e6544e9b0ffe8697
#                 .addData(data);
#         }
#             geo_json_c7e17a885f6f6c70e6544e9b0ffe8697_add({&quot;bbox&quot;: [-90.28265131173805, -0.6617767381225262, -90.23399308705744, -0.6264813441363699], &quot;features&quot;: [{&quot;bbox&quot;: [-90.25202479902259, -0.6445876365081908, -90.24286652338881, -0.6344264474701411], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-90.24773091365195, -0.6344264474701411], [-90.25202479902259, -0.6372912246966786], [-90.25173968758577, -0.6423717850529794], [-90.24716054356507, -0.6445876365081908], [-90.24286652338881, -0.6417227694598883], [-90.24315178203757, -0.636

# %% [markdown]
# ### work on all

# %%
temp_df = tortoise_tiled['tile_ID'].value_counts()
tortoise_tiled_count = pd.DataFrame({'tile_ID': temp_df.index, 'count': temp_df.values})
tortoise_tiled_count.set_index("tile_ID",inplace=True)
tessellation_count = tessellation.set_index('tile_ID')
tessellation_count = tessellation_count.merge(tortoise_tiled_count, on = "tile_ID")

# %%
center = [(tessellation_count["geometry"].centroid.y.min() + tessellation_count["geometry"].centroid.y.max())/2, \
        (tessellation_count["geometry"].centroid.x.min() + tessellation_count["geometry"].centroid.x.max())/2]
linear_color = cm.LinearColormap(['green', 'yellow', 'red'], vmin=0, vmax=math.log(tessellation_count["count"].max()))
f = folium.Figure(width=1000, height=500)
m = folium.Map(location=center, zoom_start=14, min_zoom=2, max_bounds=True, tiles='cartodbpositron').add_to(f)
folium.GeoJson(tessellation_count, style_function=lambda feature: {
        'fill': True,
        'color': 'darkgrey' if feature['properties']['count']==0 else \
                linear_color(math.log(float(feature['properties']['count']))),
        'weight' : 0.3,
        'fillOpacity' : 0.5,
        'label': "tile_ID"
        }).add_to(m)
m
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ba8402cb1035f10eb39815ef8212ac1c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ba8402cb1035f10eb39815ef8212ac1c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ba8402cb1035f10eb39815ef8212ac1c = L.map(
#                 &quot;map_ba8402cb1035f10eb39815ef8212ac1c&quot;,
#                 {
#                     center: [-0.6904282554766976, -90.3481789477044],
#                     crs: L.CRS.EPSG3857,
#                     maxBounds: [[-90, -180], [90, 180]],
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dbed33de6294ee5a610d31305acb766b = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 2, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_dbed33de6294ee5a610d31305acb766b.addTo(map_ba8402cb1035f10eb39815ef8212ac1c);
#
#
#         function geo_json_9d222679bd54353a794a1a66f7fda53b_styler(feature) {
#             switch(feature.id) {
#                 case &quot;886c5bb0bdfffff&quot;: case &quot;886c5ba257fffff&quot;:
#                     return {&quot;color&quot;: &quot;#ffd400ff&quot;, &quot;fill&quot;: true, &quot;fillOpacity&quot;: 0.5, &quot;label&quot;: &quot;tile_ID&quot;, &quot;weight&quot;: 0.3};
#                 case &quot;886c597921fffff&quot;:
#                     return {&quot;color&quot;: &quot;#ff5f00ff&quot;, &quot;fill&quot;: true, &quot;fillOpacity&quot;: 0.5, &quot;label&quot;: &quot;tile_ID&quot;, &quot;weight&quot;: 0.3};
#                 case &quot;886c5ba249fffff&quot;:
#                     return {&quot;color&quot;: &quot;#ff6d00ff&quot;, &quot;fill&quot;: true, &quot;fillOpacity&quot;: 0.5, &quot;label&quot;: &quot;tile_ID&quot;, &quot;weight&quot;: 0.3};
#                 case &quot;886c5bb0adfffff&quot;:
#                     return {&quot;color&quot;: &quot;#fff000ff&quot;, &quot;fill&quot;: true, &quot;fillOpacity&quot;: 0.5, &quot;label&quot;: &quot;tile_ID&quot;, &quot;weight&quot;: 0.3};
#                 case &quot;886c5bb0b5fffff&quot;:
#                     return {&quot;color&quot;: &quot;#ff9700ff&quot;, &quot;fill&quot;: true, &quot;fillOpacity&quot;: 0.5, &quot;label&quot;: &quot;tile_ID&quot;, &quot;weight&quot;: 0.3};
#                 case &quot;886c597961fffff&quot;: case &quot;886c5bb0bbfffff&quot;:
#                     return {&quot;color&quot;: &quot;#ff5b00ff&quot;, &quot;fill&quot;: true, &quot;fillOpacity&quot;: 0.5, &quot;label&quot;: &quot;tile_ID&quot;, &quot;weight&quot;: 0.3};
#                 case &quot;886c5bb653fffff&quot;: case &quot;886c5bb197fffff&quot;:
#                     return {&quot;color&quot;: &quot;#e5f200ff&quot;, &quot;fill&quot;: true, &quot;fillOpacity&quot;: 0.5, &quot;label&quot;: &quot;tile_ID&quot;, &quot;weight&quot;: 0.3};
#                 case &quot;886c5ba201fffff&quot;: case &quot;886c5bb569fffff&quot;: case &quot;886c5bb659fffff&quot;:
#                     return {&quot;color&quot;: &quot;#ff9900ff&quot;, &quot;fill&quot;: true, &quot;fillOpacity&quot;: 0.5, &quot;label&quot;: &quot;tile_ID&quot;, &quot;weight&quot;: 0.3};
#                 case &quot;886c5bb09bfffff&quot;:
#                     return {&quot;color&quot;: &quot;#3b9e00ff&quot;, &quot;fill&quot;: true, &quot;fillOpacity&quot;: 0.5, &quot;label&quot;: &quot;tile_ID&quot;, &quot;weight&quot;: 0.3};
#                 case &quot;886c597949fffff&quot;: case &quot;886c5bb0a3fffff&quot;:
#                     return {&quot;color&quot;: &quot;#ff8800ff&quot;, &quot;fill&quot;: true, &quot;fillOpacity&quot;: 0.5, &quot;label&quot;: &quot;tile_ID&quot;, &quot;weight&quot;: 0.3};
#                 case &quot;886c5ba26bfffff&quot;:
#                     return {&quot;color&quot;: &quot;#ffbd00ff&quot;, &quot;fill&quot;: true, &quot;fillOpacity&quot;: 0.5, &quot;label&quot;: &quot;tile_ID&quot;, &quot;weight&quot;: 0.3};
#                 case &quot;886c597901fffff&quot;:
#                     return {&quot;color&quot;: &quot;#ffe900ff&quot;, &quot;fill&quot;: true, &quot;fillOpacity&quot;: 0.5, &quot;label&quot;: &quot;tile_ID&quot;, &quot;weight&quot;: 0.3};
#                 case &quot;886c5bb541fffff&quot;:
#                     return {&quot;color&quot;: &quot;#ffd800ff&quot;, &quot;fill&quot;: true, &quot;fillOpacity&quot;: 0.5, &quot;label&quot;: &quot;tile_ID&quot;, &quot;weight&quot;: 0.3};
#                 case &quot;886c5bb537fffff&quot;:
#                     return {&quot;color&quot;: &quot;#dbed00ff&quot;, &quot;fill&quot;: true, &quot;fillOpacity&quot;: 0.5, &quot;label&quot;: &quot;tile_ID&quot;, &quot;weight&quot;: 0.3};
#                 case &quot;886c5bb601fffff&quot;:
#                     return {&quot;color&quot;: &quot;#ffef00ff&quot;, &quot;fill&quot;: true, &quot;fillOpacity&quot;: 0.5, &quot;label&quot;: &quot;tile_ID&quot;, &quot;weight&quot;: 0.3};
#                 case &quot;886c5bb097fffff&quot;:
#                     return {&quot;color&quot;: &quot;#c6e300ff&quot;, &quot;fill&quot;: true, &quot;fillOpacity&quot;: 0.5, &quot;label&quot;: &quot;tile_ID&quot;, &quot;w

# %%
import branca.colormap as cm

import math
linear = cm.LinearColormap(['green', 'yellow', 'red'], vmin=0, vmax=math.log(alison_tiled_count.max()))


f = folium.Figure(width=1000, height=500)
m = folium.Map(location=[-0.65, -90.35], zoom_start=13, min_zoom=2, max_bounds=True, tiles='cartodbpositron').add_to(f)
folium.GeoJson(tessellation_count, style_function=lambda feature: {
        'fill': True,
        'color': 'lightgrey' if feature['properties']['count']==0 else \
                linear(math.log(float(feature['properties']['count']))),
                #linear.to_step(n=6,data = [30.6, 50, 51, 52, 53, 54, 55, 60, 70, 100],  method = 'quantiles')(float(feature['properties']['count'])),
        'weight' : 0.3,
        'fillOpacity' : 0.5,
        'label': "abcd"

        }).add_to(m)

m
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d5d1ff6cf9dc7cfdba99751b02ecb3c4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d5d1ff6cf9dc7cfdba99751b02ecb3c4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d5d1ff6cf9dc7cfdba99751b02ecb3c4 = L.map(
#                 &quot;map_d5d1ff6cf9dc7cfdba99751b02ecb3c4&quot;,
#                 {
#                     center: [-0.65, -90.35],
#                     crs: L.CRS.EPSG3857,
#                     maxBounds: [[-90, -180], [90, 180]],
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e78f97c5277bd83bcf6b1af5fc45e358 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 2, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_e78f97c5277bd83bcf6b1af5fc45e358.addTo(map_d5d1ff6cf9dc7cfdba99751b02ecb3c4);
#
#
#         function geo_json_c3d284f4e6e0f8c64f05bdf84359e49e_styler(feature) {
#             switch(feature.id) {
#                 case &quot;886c5bb0bdfffff&quot;: case &quot;886c5ba257fffff&quot;:
#                     return {&quot;color&quot;: &quot;#ff9b00ff&quot;, &quot;fill&quot;: true, &quot;fillOpacity&quot;: 0.5, &quot;label&quot;: &quot;abcd&quot;, &quot;weight&quot;: 0.3};
#                 case &quot;886c597921fffff&quot;: case &quot;886c59796dfffff&quot;:
#                     return {&quot;color&quot;: &quot;#ff1000ff&quot;, &quot;fill&quot;: true, &quot;fillOpacity&quot;: 0.5, &quot;label&quot;: &quot;abcd&quot;, &quot;weight&quot;: 0.3};
#                 case &quot;886c5ba249fffff&quot;:
#                     return {&quot;color&quot;: &quot;#ff2100ff&quot;, &quot;fill&quot;: true, &quot;fillOpacity&quot;: 0.5, &quot;label&quot;: &quot;abcd&quot;, &quot;weight&quot;: 0.3};
#                 case &quot;886c5bb0adfffff&quot;: case &quot;886c5bb601fffff&quot;:
#                     return {&quot;color&quot;: &quot;#ffbc00ff&quot;, &quot;fill&quot;: true, &quot;fillOpacity&quot;: 0.5, &quot;label&quot;: &quot;abcd&quot;, &quot;weight&quot;: 0.3};
#                 case &quot;886c5bb0b5fffff&quot;: case &quot;886c594c97fffff&quot;:
#                     return {&quot;color&quot;: &quot;#ff5300ff&quot;, &quot;fill&quot;: true, &quot;fillOpacity&quot;: 0.5, &quot;label&quot;: &quot;abcd&quot;, &quot;weight&quot;: 0.3};
#                 case &quot;886c597961fffff&quot;: case &quot;886c5bb0bbfffff&quot;: case &quot;886c5ba263fffff&quot;:
#                     return {&quot;color&quot;: &quot;#ff0c00ff&quot;, &quot;fill&quot;: true, &quot;fillOpacity&quot;: 0.5, &quot;label&quot;: &quot;abcd&quot;, &quot;weight&quot;: 0.3};
#                 case &quot;886c5bb653fffff&quot;: case &quot;886c5bb197fffff&quot;:
#                     return {&quot;color&quot;: &quot;#ffef00ff&quot;, &quot;fill&quot;: true, &quot;fillOpacity&quot;: 0.5, &quot;label&quot;: &quot;abcd&quot;, &quot;weight&quot;: 0.3};
#                 case &quot;886c5ba201fffff&quot;:
#                     return {&quot;color&quot;: &quot;#ff5600ff&quot;, &quot;fill&quot;: true, &quot;fillOpacity&quot;: 0.5, &quot;label&quot;: &quot;abcd&quot;, &quot;weight&quot;: 0.3};
#                 case &quot;886c5bb09bfffff&quot;:
#                     return {&quot;color&quot;: &quot;#46a300ff&quot;, &quot;fill&quot;: true, &quot;fillOpacity&quot;: 0.5, &quot;label&quot;: &quot;abcd&quot;, &quot;weight&quot;: 0.3};
#                 case &quot;886c597949fffff&quot;: case &quot;886c5bb0a3fffff&quot;:
#                     return {&quot;color&quot;: &quot;#ff4100ff&quot;, &quot;fill&quot;: true, &quot;fillOpacity&quot;: 0.5, &quot;label&quot;: &quot;abcd&quot;, &quot;weight&quot;: 0.3};
#                 case &quot;886c5ba26bfffff&quot;:
#                     return {&quot;color&quot;: &quot;#ff8100ff&quot;, &quot;fill&quot;: true, &quot;fillOpacity&quot;: 0.5, &quot;label&quot;: &quot;abcd&quot;, &quot;weight&quot;: 0.3};
#                 case &quot;886c597901fffff&quot;:
#                     return {&quot;color&quot;: &quot;#ffb400ff&quot;, &quot;fill&quot;: true, &quot;fillOpacity&quot;: 0.5, &quot;label&quot;: &quot;abcd&quot;, &quot;weight&quot;: 0.3};
#                 case &quot;886c5bb541fffff&quot;:
#                     return {&quot;color&quot;: &quot;#ffa100ff&quot;, &quot;fill&quot;: true, &quot;fillOpacity&quot;: 0.5, &quot;label&quot;: &quot;abcd&quot;, &quot;weight&quot;: 0.3};
#                 case &quot;886c5bb537fffff&quot;:
#                     return {&quot;color&quot;: &quot;#fffb00ff&quot;, &quot;fill&quot;: true, &quot;fillOpacity&quot;: 0.5, &quot;label&quot;: &quot;abcd&quot;, &quot;weight&quot;: 0.3};
#                 case &quot;886c5bb097fffff&quot;:
#                     return {&quot;color&quot;: &quot;#ecf600ff&quot;, &quot;fill&quot;: true, &quot;fillOpacity&quot;: 0.5, &quot;label&quot;: &quot;abcd&quot;, &quot;weight&quot;: 0.3};
#                 case &quot;886c597941fffff&quot;: case &quot;886c5ba2c9fffff&quot;: case &quot;886c5bb0ebfffff&quot;:
#                     return {&quot;color&quot;: &quot;#008000ff&quot;, &quot;fill&quot;: true, &quot;fillO

# %% [raw]
# f = folium.Figure(width=1000, height=500)
# m = folium.Map(location=[-0.65, -90.35], zoom_start=12, min_zoom=2, max_bounds=True).add_to(f)
# folium.GeoJson(tessellation).add_to(m)
# m

# %% [raw]
# from skmob.utils import plot
# tessellation = tilers.tiler.get("squared", base_shape="isla santa cruz", meters=100)
# tess_style = {'color':'lightgrey', 'fillColor':None, 'weight': 0.5}
# popup_features=['tile_ID']
# map_f = plot.plot_gdf(tessellation, zoom=14, style_func_args=tess_style,
#              popup_features=popup_features)
# map_f
